# %%
import pandas as pd
from pathlib import Path
import json

df = pd.read_csv("src/data/population_by_country.tsv", sep="\t", header=None, thousands=',')
df.columns = ['country','population']
df.population = df.population/1000

stats = {"stats": dict(zip(df.country, df.population)),
 "desc": "Guess 3 countries whose population sums to",
 "unit": "million",
 "aim": 180,
 "inner_bull": 5,
 "outer_bull": 10}
Path("data/info.json").write_text(json.dumps(stats))
# Out:
# 4724

# %%
import pandas as pd
from pathlib import Path
import json

df = pd.read_csv("src/data/life_expectancy.csv", sep=",")
# df.columns = ['country','population']

# df.population = df.population/1000

stats = {"stats": dict(zip(df.Country, df['Life Expectancy (both sexes)'])),
 "desc": "Guess 3 countries whose life expectancy sums to",
 "unit": "years",
 "aim": 180,
 "inner_bull": 5,
 "outer_bull": 10}
Path("src/data/info.json").write_text(json.dumps(stats))
df
# Out:
#      Rank                   Country  Life Expectancy (both sexes)  \
# 0       1                 Hong Kong                         85.77
# 1       2                     Japan                         85.00
# 2       3               South Korea                         84.53
# 3       4          French Polynesia                         84.31
# 4       5               Switzerland                         84.23
# ..    ...                       ...                           ...
# 196   197                   Lesotho                         58.22
# 197   198  Central African Republic                         57.90
# 198   199               South Sudan                         57.85
# 199   200                      Chad                         55.43
# 200   201                   Nigeria                         54.78
#
#      Females Life Expectancy  Males Life Expectancy
# 0                      88.39                  83.10
# 1                      88.03                  81.99
# ...

# %%
# !cp src/data/info.json src/data/countries.json

# %%
df = pd.DataFrame(zip(['Songs for Fin volume 3', '
# Out:
# info.json

# %%
# !ls src/data/
# Out:
# countries.json      info.json           life_expectancy.csv
